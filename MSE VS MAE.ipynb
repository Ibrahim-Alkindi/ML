# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
X = np.random.randint(1, 500, size = 300)
y = (X + 4) * 0.6

# %%
X.shape, y.shape
# Out:
# ((300,), (300,))

# %%
df = pd.DataFrame({
    'X':X,
    'y':y
})

# %%
df
# Out:
#        X      y
# 0    337  204.6
# 1      6    6.0
# 2    203  124.2
# 3    139   85.8
# 4     39   25.8
# ..   ...    ...
# 295  186  114.0
# 296  180  110.4
# 297  153   94.2
# 298  193  118.2
# 299  387  234.6
#
# [300 rows x 2 columns]

# %%
X = X.reshape(-1,1)
y = y.reshape(-1,1)
LR_model = LinearRegression()
LR_model.fit(X,y)
# Out:
# LinearRegression()

# %%
pred = LR_model.predict(X)

# %%
df['y_hat'] = pred

# %%
df
# Out:
#        X      y  y_hat
# 0    337  204.6  204.6
# 1      6    6.0    6.0
# 2    203  124.2  124.2
# 3    139   85.8   85.8
# 4     39   25.8   25.8
# ..   ...    ...    ...
# 295  186  114.0  114.0
# 296  180  110.4  110.4
# 297  153   94.2   94.2
# 298  193  118.2  118.2
# 299  387  234.6  234.6
#
# [300 rows x 3 columns]

# %%
MSE = mean_squared_error(df['y'],df['y_hat'])
MSE
# Out:
# 3.1101367095608537e-28

# %%
MAE = mean_absolute_error(df['y'],df['y_hat'])
MAE
# Out:
# 8.855138844410249e-15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.99, random_state=42)

# %%
X_train = X_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test = X_test.reshape(-1,1)
perd = model.predict(X_test)

# %%
df1 = pd.DataFrame(perd, columns = ['y_hat'])
df1
# Out:
#      y_hat
# 0    282.6
# 1     93.6
# 2     18.0
# 3    163.2
# 4    246.0
# ..     ...
# 292  155.4
# 293  234.6
# 294   70.2
# 295  199.8
# 296  104.4
#
# [297 rows x 1 columns]

# %%
perd.shape
# Out:
# (297, 1)

# %%
mae = mean_absolute_error(df['y'],df1['y_hat'])
mae
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 mae = mean_absolute_error(df['y'],df1['y_hat'])
#       2 mae
#
# File /opt/conda/envs/py39_ml/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File /opt/conda/envs/py39_ml/lib/python3.9/site-packages/sklearn/metrics/_regression.py:277, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     222 """Mean absolute error regression loss.
#     223
#     224 Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     272 0.85...
#     273 """
#     274 xp, _ = get_namespace(y_true, y_pred, sample_weight, multioutput)
#     276 _, y_true, y_pred, sample_weight, multioutput = (
# --> 277     _check_reg_targets_with_floating_dtype(
#     278         y_true, y_pred, sample_weight, multioutput, xp=xp
#     279     )
#     280 )
#     282 check_consistent_length(y_true, y_pred, sample_weight)
#     284 output_errors = _average(
#     285     xp.abs(y_pred - y_true), weights=sample_weight, axis=0, xp=xp
#     286 )
#
# File /opt/conda/envs/py39_ml/lib/python3.9/site-packages/sklearn/metrics/_regression.py:198, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     148 """Ensures that y_true, y_pred, and sample_weight correspond to the same
#     149 regression task.
#     150
#    (...)
#     194     correct keyword.
#     195 """
#     196 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 198 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     199     y_true, y_pred, multioutput, dtype=dtype_name, xp=xp
#     200 )
#     202 # _check_reg_targets does not accept sample_weight as input.
#     203 # Convert sample_weight's data type separately to match dtype_name.
#     204 if sample_weight is not None:
#
# File /opt/conda/envs/py39_ml/lib/python3.9/site-packages/sklearn/metrics/_regression.py:104, in _check_reg_targets(y_true, y_pred, multioutput, dtype, xp)
#      59 """Check that y_true and y_pred belong to the same regression task.
#      60
#      61 To reduce redundancy when calling `_find_matching_floating_dtype`,
#    (...)
#     100     correct keyword.
#     101 """
#     102 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
# --> 104 check_consistent_length(y_true, y_pred)
#     105 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     106 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File /opt/conda/envs/py39_ml/lib/python3.9/site-packages/sklearn/utils/validation.py:475, in check_consistent_length(*arrays)
#     473 uniques = np.unique(lengths)
#     474 if len(uniques) > 1:
# --> 475     raise ValueError(
#     476         "Found input variables with inconsistent numbers of samples: %r"
#     477         % [int(l) for l in lengths]
#     478     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [300, 297]

# %%
mse = mean_squared_error(df['y'],df['y_hat_new'])
mse
# Out:
# 2.456710074084536e-29

# %%
y = np.random.randint(0, 20, size = 20)
y_hat = np.random.randint(0, 20, size = 20)

# %%
df_new = pd.DataFrame({
    'y': y,
    'y_hat':y_hat
})

# %%
df_new
# Out:
#      y  y_hat
# 0   10      5
# 1    3      3
# 2    7     18
# 3    5      8
# 4   19      3
# 5   13     16
# 6   11     13
# 7    8     15
# 8   11      4
# 9   11      2
# 10   1      7
# 11   9     11
# 12   6     11
# 13   3     18
# 14   8     17
# 15  17     18
# 16   3     14
# 17   9      9
# 18  11     11
# 19  12      0

# %%
df_new['y - y_hat'] = df_new['y'] - df_new['y_hat']

# %%
df_new
# Out:
#      y  y_hat  y - y_hat
# 0   10      5          5
# 1    3      3          0
# 2    7     18        -11
# 3    5      8         -3
# 4   19      3         16
# 5   13     16         -3
# 6   11     13         -2
# 7    8     15         -7
# 8   11      4          7
# 9   11      2          9
# 10   1      7         -6
# 11   9     11         -2
# 12   6     11         -5
# 13   3     18        -15
# 14   8     17         -9
# 15  17     18         -1
# 16   3     14        -11
# 17   9      9          0
# 18  11     11          0
# 19  12      0         12

# %%
MSE_NEW = mean_squared_error(df_new['y'],df_new['y_hat'])
MSE_NEW
# Out:
# 62.0

# %%
MAE_NEW = mean_absolute_error(df_new['y'],df_new['y_hat'])
MAE_NEW
# Out:
# 6.2

# %%
df_new['sqe'] = np.square(df_new['y - y_hat'])
df_new['abs'] = np.abs(df_new['y - y_hat'])

# %%
df_new
# Out:
#      y  y_hat  y - y_hat  sqe  abs
# 0   10      5          5   25    5
# 1    3      3          0    0    0
# 2    7     18        -11  121   11
# 3    5      8         -3    9    3
# 4   19      3         16  256   16
# 5   13     16         -3    9    3
# 6   11     13         -2    4    2
# 7    8     15         -7   49    7
# 8   11      4          7   49    7
# 9   11      2          9   81    9
# 10   1      7         -6   36    6
# 11   9     11         -2    4    2
# 12   6     11         -5   25    5
# 13   3     18        -15  225   15
# 14   8     17         -9   81    9
# 15  17     18         -1    1    1
# 16   3     14        -11  121   11
# 17   9      9          0    0    0
# 18  11     11          0    0    0
# 19  12      0         12  144   12

# %%
sum(df_new["sqe"]) / df_new.__len__()
# Out:
# 62.0

# %%
sum(df_new['abs']) / df_new.__len__()
# Out:
# 6.2
